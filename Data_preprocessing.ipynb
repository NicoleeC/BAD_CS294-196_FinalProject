# %% [markdown]
# # Data preprocessing

# %%
import os
import json
import gzip
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import seaborn as sns
from tqdm import tqdm
from matplotlib import pyplot as plt
from urllib.request import urlopen
from numpy.linalg import norm
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt

# default plot configurations 
# %matplotlib inline 
plt.rcParams['figure.figsize'] = (16,8)
plt.rcParams['figure.dpi'] = 150
sns.set()

# %% [markdown]
# ## Start loading data

# %%
data = json.load(open('dataset/nft_tweets.json'))

# %%
df = pd.read_json('dataset/nft_tweets.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 df = pd.read_json('dataset/nft_tweets.json')
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:199, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     197     else:
#     198         kwargs[new_arg_name] = new_arg_value
# --> 199 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:299, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     294     msg = (
#     295         f"Starting with Pandas version {version} all arguments of "
#     296         f"{func.__name__}{arguments} will be keyword-only"
#     297     )
#     298     warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py:563, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options)
#     560     return json_reader
#     562 with json_reader:
# --> 563     return json_reader.read()
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py:694, in JsonReader.read(self)
#     692         obj = self._get_object_parser(self._combine_lines(data_lines))
#     693 else:
# --> 694     obj = self._get_object_parser(self.data)
#     695 self.close()
#     696 return obj
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py:716, in JsonReader._get_object_parser(self, json)
#     714 obj = None
#     715 if typ == "frame":
# --> 716     obj = FrameParser(json, **kwargs).parse()
#     718 if typ == "series" or obj is None:
#     719     if not isinstance(dtype, bool):
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py:831, in Parser.parse(self)
#     828     self._parse_numpy()
#     830 else:
# --> 831     self._parse_no_numpy()
#     833 if self.obj is None:
#     834     return None
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py:1078, in FrameParser._parse_no_numpy(self)
#    1075 orient = self.orient
#    1077 if orient == "columns":
# -> 1078     self.obj = DataFrame(
#    1079         loads(json, precise_float=self.precise_float), dtype=None
#    1080     )
#    1081 elif orient == "split":
#    1082     decoded = {
#    1083         str(k): v
#    1084         for k, v in loads(json, precise_float=self.precise_float).items()
#    1085     }
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:529, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     524     mgr = self._init_mgr(
#     525         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     526     )
#     528 elif isinstance(data, dict):
# --> 529     mgr = init_dict(data, index, columns, dtype=dtype)
#     530 elif isinstance(data, ma.MaskedArray):
#     531     import numpy.ma.mrecords as mrecords
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py:287, in init_dict(data, index, columns, dtype)
#     281     arrays = [
#     282         arr if not isinstance(arr, ABCIndexClass) else arr._data for arr in arrays
#     283     ]
#     284     arrays = [
#     285         arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286     ]
# --> 287 return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py:80, in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      77 if verify_integrity:
#      78     # figure out the index, if necessary
#      79     if index is None:
# ---> 80         index = extract_index(arrays)
#      81     else:
#      82         index = ensure_index(index)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py:404, in extract_index(data)
#     401     raise ValueError("arrays must all be same length")
#     403 if have_dicts:
# --> 404     raise ValueError(
#     405         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     406     )
#     408 if have_series:
#     409     assert index is not None  # for mypy
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %% [markdown]
# ### Load author data

# %%
author_data = pd.DataFrame(data["data"])
author_data.groupby("author_id")
author_data = author_data.drop(columns="geo")
author_data
# Out:
#                                           public_metrics  \
# 0      {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 1      {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2      {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3      {'retweet_count': 0, 'reply_count': 3, 'like_c...
# 4      {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                  ...
# 28728  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 28729  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 28730  {'retweet_count': 7, 'reply_count': 6, 'like_c...
# 28731  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 28732  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                     text  \
# 0      Yet not a single app works.\n\nWE NEED BADLY a...
# 1      @binance CYLUM $ project will be one of the mo...
# 2      @SenorAxie @CryptoGeekzNFT @PickwinkangNFT @gu...
# 3      Big yikes if these AI platforms are rememberin...
# 4      Put your NFT's on Public Display..\nAnywhere.....
# ...                                                  ...
# 28728  👉 I just joined the movement! #BlueZilla's mak...
# 28729  👉 I just joined the movement! #BlueZilla's mak...
# 28730  FairLaunch coming soon at Pinksale!\n\nStart: ...
# 28731  The only NFT collection that gives you access ...
# 28732  👉 I just joined the movement! #BlueZilla's mak...
#
#                      created_at                   id            author_id
# 0      2022-04-28T00:29:47.000Z  1519473920704983042  1181641903009341440
# 1      2022-04-28T00:29:21.000Z  1519473810793242626  1441693405583593478
# 2      2022-04-28T00:29:09.000Z  1519473760273039360           3008000582
# 3      2022-04-28T00:28:46.000Z  1519473664294535170  1208948613189160961
# 4      2022-04-28T00:28:33.000Z  1519473608237662210           2542802983
# ...                         ...                  ...                  ...
# 28728  2022-05-03T23:49:34.000Z  1521638124455145472   755561434931572737
# 28729  2022-05-03T23:49:24.000Z  1521638083749453825  1464617797011623939
# 28730  2022-05-03T23:49:13.000Z  1521638038568411137  1519004956136816642
# 28731  2022-05-03T23:49:06.000Z  1521638009032093696  1517595559011528705
# 28732  2022-05-03T23:48:58.000Z  1521637975318220801             18957343
#
# [28733 rows x 5 columns]

# %% [markdown]
# ### Follower data

# %%
follower_data_raw = data["includes"]
follower_data_raw
# Out:
# {'users': [{'id': '1181641903009341440',
#    'public_metrics': {'followers_count': 509,
#     'following_count': 512,
#     'tweet_count': 39015,
#     'listed_count': 6},
#    'username': 'cryptoken_board',
#    'name': 'cryptoken board ℠'},
#   {'id': '1441693405583593478',
#    'public_metrics': {'followers_count': 5,
#     'following_count': 56,
#     'tweet_count': 414,
#     'listed_count': 3},
#    'username': 'AliGhiasvand77',
#    'name': 'Anonymous boy'},
#   {'id': '3008000582',
#    'public_metrics': {'followers_count': 556,
#     'following_count': 1320,
#     'tweet_count': 10098,
#     'listed_count': 2},
#    'username': 'Jeruk4444',
#    'name': '█║Nash║▌🌟'},
#   {'id': '1208948613189160961',
#    'public_metrics': {'followers_count': 477,
#     'following_count': 74,
#     'tweet_count': 335,
#     'listed_count': 3},
#    'username': 'BeckerrJon',
#    'name': 'Jonathan Becker | jbecker.eth'},
#   {'id': '2542802983',
#    'public_metrics': {'followers_count': 433,
#     'following_count': 3641,
#     'tweet_count': 6029,
#     'listed_count': 11},
#    'username': 'DaLeewoke',
#    'name': 'DaLee Woke'},
#   {'id': '1385040811621036042',
#    'public_metrics': {'followers_count': 9296,
#     'following_count': 9525,
#     'tweet_count': 8294,
#     'listed_count': 18},
#    'username': 'cryptosklletons',
#    'name': 'SKLLE REMIX CLUB (SRC) | PRESALE MAY 12'},
#   {'id': '1508059975754596353',
#    'public_metrics': {'followers_count': 18,
#     'following_count': 60,
#     'tweet_count': 7,
#     'listed_count': 0},
#    'username': 'OccamLester',
#    'name': 'GCuidz03😇'},
#   {'id': '1382427530314022912',
#    'public_metrics': {'followers_count': 1682,
#     'following_count': 2,
#     'tweet_count': 19043,
#     'listed_count': 12},
#    'username': '_Crypto_Alerts',
#    'name': 'CRYPTO ALERTS'},
#   {'id': '1436354760085581826',
#    'public_metrics': {'followers_count': 6332,
#     'following_count': 274,
#     'tweet_count': 2395,
#     'listed_count': 15},
#    'username': 'PlanetMoze',
#    'name': 'Moze'},
#   {'id': '1484665357369413635',
#    'public_metrics': {'followers_count': 379,
#     'following_count': 120,
#     'tweet_count': 548,
#     'listed_count': 3},
#    'username': 'DickfaceNfts',
#    'name': 'dickface NFTs'},
#   {'id': '1072505676952465408',
#    'public_metrics': {'followers_count': 1076,
#     'following_count': 4720,
#     'tweet_count': 1017,
#     'listed_count': 0},
#    'username': 'Sexy_Asian_MILF',
#    'name': 'Sexy Asian MILF'},
#   {'id': '1376954378595180550',
#    'public_metrics': {'followers_count': 576,
#     'following_count': 1679,
#     'tweet_count': 9461,
#     'listed_count': 17},
#    'username': 'droptown_io',
#    'name': 'droptown.io'},
#   {'id': '800154160456794112',
#    'public_metrics': {'followers_count': 1222,
#     'following_count': 636,
#     'tweet_count': 5071,
#     'listed_count': 51},
#    'username': 'ahmad_manasrah1',
#    'name': '👑👑CRYPTO KING👑👑'},
#   {'id': '1279707556445855744',
#    'public_metrics': {'followers_count': 2125,
#     'following_count': 4974,
#     'tweet_count': 17621,
#     'listed_count': 3},
#    'username': '1969Rizwan',
#    'name': 'Rizwan-1969'},
#   {'id': '1508724494181056515',
#    'public_metrics': {'followers_count': 6,
#     'following_count': 1,
#     'tweet_count': 1315,
#     'listed_count': 0},
#    'username': 'nftinvest84',
#    'name': 'nft investor'},
#   {'id': '1281207710596370433',
#    'public_metrics': {'followers_count': 13,
#     'following_count': 1511,
#     'tweet_count': 3558,
#     'listed_count': 5},
#    'username': 'shehzadkh7700',
#    'name': 'Muhammad Shehzad'},
#   {'id': '1460813741285539840',
#    'public_metrics': {'followers_count': 118,
#     'following_count': 1593,
#     'tweet_count': 11940,
#     'listed_count': 5},
#    'username': 'diyan_shinta',
#    'name': 'Diyan Shinta'},
#   {'id': '1392602286078275587',
#    'public_metrics': {'followers_count': 390,
#     'following_count': 529,
#     'tweet_count': 1825,
#     'listed_count': 6},
#    'username': 'FireSta80809671',
#    'name': 'Fire Starter'},
#   {'id': '1518723962343153664',
#    'public_metrics': {'followers_count': 4,
#     'following_count': 55,
#     'tweet_count': 7,
#     'listed_count': 0},
#    'username': 'megapintnft',
#    'name': 'megapintnft'},
#   {'id': '1517561236199669761',
#    'public_metrics': {'followers_count': 47,
#     'following_count': 432,
#     'tweet_count': 9,
#     'listed_count': 0},
#    'username': 'geijutsunft',
#    'name': 'GEIJUTSU'},
#   {'id': '1499793975875670018',
#    'public_metrics': {'followers_count': 156,
#     'following_count': 567,
#     'tweet_count': 85,
#     'listed_count': 0},
#    'username': 'NFTBananaBums',
#    'name': 'Banana Bums'},
#   {'id': '1481821384594837511',
#    'public_metrics': {'followers_count': 15,
#     'following_count': 500,
#     'tweet_count': 1027,
#     'listed_count': 1},
#    'username': 'yudhapks99',
#    'name': 'Yudha Prakasa'},
#   {'id': '1512718548015398916',
#    'public_metrics': {'followers_count': 67,
#     'following_count': 12,
#     'tweet_count': 51,
#     'listed_count': 0},
#    'username': 'AllOfUsAreEggs',
#    'name': 'All Of Us Are Eggs NFT'},
#   {'id': '1490252534262292480',
#    'public_metrics': {'followers_count': 2,
#     'following_count': 0,
#     'tweet_count': 28,
#     'listed_count': 0},
#    'username': 'NobrainersBot',
#    'name': 'NoBrainers - Sales bot'},
#   {'id': '1468280210885951492',
#    'public_metrics': {'followers_count': 760,
#     'following_count': 1248,
#     'tweet_count': 35712,
#     'listed_count': 61},
#    'username': 'PartyGuy6969',
#    'name': 'Party Guy'},
#   {'id': '1481288259640733696',
#    'public_metrics': {'followers_count': 236,
#     'following_count': 279,
#     'tweet_count': 565,
#     'listed_count': 20},
#    'username': 'cryptomarketguy',
#    'name': 'Crypto Investor Report'},
#   {'id': '1500249423376437248',
#    'public_metrics': {'followers_count': 808,
#     'following_count': 977,
#     'tweet_count': 129,
#     'listed_count': 2},
#    'username': 'jbabs_art',
#    'name': 'jbabs'},
#   {'id': '1498047859396321280',
#    'public_metrics': {'followers_count': 161,
#     'following_count': 466,
#     'tweet_count': 5567,
#     'listed_count': 0},
#    'username': 'Jparke233',
#    'name': 'Jack Parker'},
#   {'id': '1403460534847090692',
#    'public_metrics': {'followers_count': 23,
#     'following_count': 15,
#     'tweet_count': 738,
#     'listed_count': 0},
#    'username': 'Nft359',
#    'name': 'Fa'},
#   {'id': '1418330979882700800',
#    'public_metrics': {'followers_count': 48,
#     'following_count': 60,
#     'tweet_count': 137,
#     'listed_count': 4},
#    'username': 'arcrevolution_',
#    'name': 'ARCrypto Educational'},
#   {'id': '1493274477895032843',
#    'public_metrics': {'followers_count': 19,
#     'following_count': 962,
#     'tweet_count': 2093,
#     'listed_count': 0},
#    'username': 'Laifaouilinda1',
#    'name': 'Laifaouilinda⚡️'},
#   {'id': '1516602424101904392',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 7,
#     'tweet_count': 327,
#     'listed_count': 0},
#    'username': 'King46390546',
#    'name': 'King'},
#   {'id': '986587482',
#    'public_metrics': {'followers_count': 340,
#     'following_count': 436,
#     'tweet_count': 2522,
#     'listed_count': 6},
#    'username': 'Xernive',
#    'name': 'They Call Me X'},
#   {'id': '1492096734872227842',
#    'public_metrics': {'followers_count': 77,
#     'following_count': 401,
#     'tweet_count': 830,
#     'listed_count': 1},
#    'username': 'DMCNewsOfficial',
#    'name': 'DMC News'},
#   {'id': '1452829216278396933',
#    'public_metrics': {'followers_count': 34,
#     'following_count': 1023,
#     'tweet_count': 3757,
#     'listed_count': 6},
#    'username': 'ekramul988',
#    'name': 'Ekramul988'},
#   {'id': '919406771134967808',
#    'public_metrics': {'followers_count': 255,
#     'following_count': 1528,
#     'tweet_count': 16249,
#     'listed_count': 12},
#    'username': 'cpansherry1777',
#    'name': 'Crypto Market Buzz'},
#   {'id': '1441443895062134788',
#    'public_metrics': {'followers_count': 16,
#     'following_count': 243,
#     'tweet_count': 31,
#     'listed_count': 5},
#    'username': 'SHIBUTRON_',
#    'name': 'OFFICIAL SHIBUTRON 🇮🇳'},
#   {'id': '1353064218501627907',
#    'public_metrics': {'followers_count': 69,
#     'following_count': 185,
#     'tweet_count': 290,
#     'listed_count': 2},
#    'username': 'TamaleChomper',
#    'name': 'TamaleChomper'},
#   {'id': '1399004170498232320',
#    'public_metrics': {'followers_count': 3567,
#     'following_count': 75,
#     'tweet_count': 3931,
#     'listed_count': 3},
#    'username': 'BerriesCrypto',
#    'name': 'Crypto Berries'},
#   {'id': '1918756567',
#    'public_metrics': {'followers_count': 650,
#     'following_count': 432,
#     'tweet_count': 3496,
#     'listed_count': 9},
#    'username': 'breathtovision',
#    'name': 'Daydream Soliloquy'},
#   {'id': '2918029454',
#    'public_metrics': {'followers_count': 1149,
#     'following_count': 1418,
#     'tweet_count': 3705,
#     'listed_count': 42},
#    'username': 'KickstandWilly',
#    'name': 'Adam E. Williams | #RoadmapforSuccess'},
#   {'id': '1419589500884471812',
#    'public_metrics': {'followers_count': 169,
#     'following_count': 580,
#     'tweet_count': 791,
#     'listed_count': 2},
#    'username': 'hiddesy1',
#    'name': 'Hidden_Angel || MetaAngelDAO || MAPE'},
#   {'id': '1436707620459581448',
#    'public_metrics': {'followers_count': 1959,
#     'following_count': 258,
#     'tweet_count': 9,
#     'listed_count': 0},
#    'username': 'Casie_Crypto',
#    'name': 'Casie'},
#   {'id': '30439677',
#    'public_metrics': {'followers_count': 1709,
#     'following_count': 179,
#     'tweet_count': 37402,
#     'listed_count': 206},
#    'username': 'Vanai',
#    'name': 'Ivana Urosevic'},
#   {'id': '1390803351734943744',
#    'public_metrics': {'followers_count': 27,
#     'following_count': 1027,
#     'tweet_count': 1979,
#     'listed_count': 1},
#    'username': 'berwas131313',
#    'name': 'Yosra'},
#   {'id': '18372181',
#    'public_metrics': {'followers_count': 4513,
#     'following_count': 3300,
#     'tweet_count': 5494,
#     'listed_count': 40},
#    'username': 'oopsalion',
#    'name': 'ØØ¶§ Á £‡ØÑ.....'},
#   {'id': '1444760013822701568',
#    'public_metrics': {'followers_count': 17,
#     'following_count': 34,
#     'tweet_count': 4495,
#     'listed_count': 0},
#    'username': 'LucioOcchipinti',
#    'name': '#Women and #Crypto'},
#   {'id': '1436514809885822985',
#    'public_metrics': {'followers_count': 885,
#     'following_count': 2132,
#     'tweet_count': 8288,
#     'listed_count': 1},
#    'username': 'spangerxyz',
#    'name': 'Raft Track'},
#   {'id': '1351182523406151686',
#    'public_metrics': {'followers_count': 536,
#     'following_count': 790,
#     'tweet_count': 751,
#     'listed_count': 0},
#    'username': 'hayhaydenL',
#    'name': 'Hayden Lewis'},
#   {'id': '1518362847117705217',
#    'public_metrics': {'followers_count': 2,
#     'following_count': 11,
#     'tweet_count': 56,
#     'listed_count': 0},
#    'username': 'Cigdedofficial',
#    'name': 'Cigded'},
#   {'id': '1451531840788078593',
#    'public_metrics': {'followers_count': 14,
#     'following_count': 34,
#     'tweet_count': 3831,
#     'listed_count': 0},
#    'username': 'tontogadgets',
#    'name': 'tontogadgets'},
#   {'id': '1488375980913692676',
#    'public_metrics': {'followers_count': 99,
#     'following_count': 26,
#     'tweet_count': 6,
#     'listed_count': 2},
#    'username': 'SolmarkNFT',
#    'name': 'Solmark NFT'},
#   {'id': '1470989326448467969',
#    'public_metrics': {'followers_count': 235,
#     'following_count': 300,
#     'tweet_count': 536,
#     'listed_count': 6},
#    'username': 'TMTWendyy',
#    'name': 'Wendy ~'},
#   {'id': '1493663603395809287',
#    'public_metrics': {'followers_count': 513,
#     'following_count': 36,
#     'tweet_count': 549,
#     'listed_count': 2},
#    'username': 'LettuceHeadsNFT',
#    'name': 'Lettuce Heads Club🥬'},
#   {'id': '1516154846981722112',
#    'public_metrics': {'followers_count': 14,
#     'following_count': 22,
#     'tweet_count': 58,
#     'listed_count': 0},
#    'username': 'DigitalPhase1',
#    'name': 'Digital Phase'},
#   {'id': '1213587855907250176',
#    'public_metrics': {'followers_count': 478,
#     'following_count': 2384,
#     'tweet_count': 1251,
#     'listed_count': 130},
#    'username': 'Ratiba25676051',
#    'name': 'Nfts creator'},
#   {'id': '783927230460198912',
#    'public_metrics': {'followers_count': 13257,
#     'following_count': 3064,
#     'tweet_count': 8449,
#     'listed_count': 3},
#    'username': 'techgenez',
#    'name': 'TechGenez.com'},
#   {'id': '1305568801161990144',
#    'public_metrics': {'followers_count': 374,
#     'following_count': 533,
#     'tweet_count': 1686,
#     'listed_count': 0},
#    'username': 'startups_expo',
#    'name': 'StartupsExpo'},
#   {'id': '1155562856710123520',
#    'public_metrics': {'followers_count': 18,
#     'following_count': 172,
#     'tweet_count': 42,
#     'listed_count': 3},
#    'username': 'iampaulkremers',
#    'name': 'paulkremers.eth'},
#   {'id': '842547942984744960',
#    'public_metrics': {'followers_count': 571,
#     'following_count': 43,
#     'tweet_count': 1340,
#     'listed_count': 0},
#    'username': 'WannabeCrypto',
#    'name': 'WannabeCrypto #XCUR'},
#   {'id': '461942103',
#    'public_metrics': {'followers_count': 542,
#     'following_count': 911,
#     'tweet_count': 12959,
#     'listed_count': 85},
#    'username': 'M17_Lpunzalan',
#    'name': 'Luis "LZ" Punzalan'},
#   {'id': '2322539420',
#    'public_metrics': {'followers_count': 3553,
#     'following_count': 3898,
#     'tweet_count': 3880,
#     'listed_count': 18},
#    'username': 'Kanube77',
#    'name': 'Crypto Family✨Honorary BTF Ape #27 ~ Click My Pic'},
#   {'name': 'Yellow Submarine',
#    'id': '1503538068690767878',
#    'public_metrics': {'followers_count': 74,
#     'following_count': 216,
#     'tweet_count': 4839,
#     'listed_count': 0},
#    'username': 'YellowSub_420'},
#   {'name': '⚡Raisya ⚡',
#    'id': '2891897349',
#    'public_metrics': {'followers_count': 3522,
#     'following_count': 4029,
#     'tweet_count': 7417,
#     'listed_count': 12},
#    'username': 'raysa_77'},
#   {'name': 'NEVERSTOP',
#    'id': '1255601741090914304',
#    'public_metrics': {'followers_count': 84,
#     'following_count': 55,
#     'tweet_count': 223,
#     'listed_count': 4},
#    'username': 'neverstop_101'},
#   {'name': 'Theta NFT BOT | ThetaLands',
#    'id': '1466126083204464647',
#    'public_metrics': {'followers_count': 653,
#     'following_count': 14,
#     'tweet_count': 7903,
#     'listed_count': 4},
#    'username': 'Theta_NFT_BOT'},
#   {'name': 'JJ-Mystic',
#    'id': '3296124525',
#    'public_metrics': {'followers_count': 125,
#     'following_count': 430,
#     'tweet_count': 537,
#     'listed_count': 3},
#    'username': 'JefMercs'},
#   {'name': 'pieté.eth',
#    'id': '1519444658564341761',
#    'public_metrics': {'followers_count': 11,
#     'following_count': 83,
#     'tweet_count': 56,
#     'listed_count': 0},
#    'username': 'PitieRoule'},
#   {'name': 'The Crooked Crocs',
#    'id': '1478258551722151936',
#    'public_metrics': {'followers_count': 139,
#     'following_count': 247,
#     'tweet_count': 119,
#     'listed_count': 1},
#    'username': 'TheCrookedCrocs'},
#   {'name': 'mahfuz',
#    'id': '1372478063292813315',
#    'public_metrics': {'followers_count': 13,
#     'following_count': 776,
#     'tweet_count': 1013,
#     'listed_count': 2},
#    'username': 'mahfuz54'},
#   {'name': 'The Frost Pipe',
#    'id': '768448094',
#    'public_metrics': {'followers_count': 1927,
#     'following_count': 2277,
#     'tweet_count': 1856,
#     'listed_count': 6},
#    'username': 'FrostPipe1'},
#   {'name': '👽🛸🧐 Crypto News--FOLLOW ME🛸👽🧐',
#    'id': '1384497485167697921',
#    'public_metrics': {'followers_count': 2336,
#     'following_count': 502,
#     'tweet_count': 22401,
#     'listed_count': 30},
#    'username': '2021Ufo'},
#   {'name': 'Maxx Finance',
#    'id': '1453118077164457990',
#    'public_metrics': {'followers_count': 404,
#     'following_count': 15,
#     'tweet_count': 49,
#     'listed_count': 1},
#    'username': 'MaxxFinance'},
#   {'name': '隣人A',
#    'id': '1486890172734005250',
#    'public_metrics': {'followers_count': 14,
#     'following_count': 189,
#     'tweet_count': 237,
#     'listed_count': 1},
#    'username': 'Cryptian14'},
#   {'name': 'Airdrop And FreeMint（Earn 100 USDT everyday）',
#    'id': '1420486738745511936',
#    'public_metrics': {'followers_count': 146,
#     'following_count': 87,
#     'tweet_count': 353,
#     'listed_count': 2},
#    'username': '528NFT'},
#   {'name': 'Meta Trends',
#    'id': '1493890573098385414',
#    'public_metrics': {'followers_count': 198,
#     'following_count': 153,
#     'tweet_count': 115,
#     'listed_count': 2},
#    'username': 'pissukannaverse'},
#   {'name': 'Party Guy',
#    'id': '1468280210885951492',
#    'public_metrics': {'followers_count': 760,
#     'following_count': 1248,
#     'tweet_count': 35712,
#     'listed_count': 61},
#    'username': 'PartyGuy6969'},
#   {'name': 'Dave Crypto',
#    'id': '1508722622808440833',
#    'public_metrics': {'followers_count': 4,
#     'following_count': 1,
#     'tweet_count': 1426,
#     'listed_count': 0},
#    'username': 'DaveCrypto2022'},
#   {'name': 'CrypticThreadz.NFT',
#    'id': '1416547300281815046',
#    'public_metrics': {'followers_count': 188,
#     'following_count': 77,
#     'tweet_count': 8214,
#     'listed_count': 8},
#    'username': 'crypticthreadz'},
#   {'name': 'Crypto Rome',
#    'id': '240547557',
#    'public_metrics': {'followers_count': 168,
#     'following_count': 370,
#     'tweet_count': 1428,
#     'listed_count': 1},
#    'username': 'bigrome80'},
#   {'name': 'Evan Robles \uea00 | EvanRobles.eth Ξ | Robles.sol 🧬',
#    'id': '1401068403553615872',
#    'public_metrics': {'followers_count': 2371,
#     'following_count': 933,
#     'tweet_count': 902,
#     'listed_count': 12},
#    'username': 'EvanRoblesC'},
#   {'name': 'droptown.io',
#    'id': '1376954378595180550',
#    'public_metrics': {'followers_count': 576,
#     'following_count': 1679,
#     'tweet_count': 9461,
#     'listed_count': 17},
#    'username': 'droptown_io'},
#   {'name': 'follower crypto💰💸💰',
#    'id': '1515374128785768466',
#    'public_metrics': {'followers_count': 3,
#     'following_count': 14,
#     'tweet_count': 2,
#     'listed_count': 0},
#    'username': 'eipstein_sigrid'},
#   {'name': 'Oleg DC',
#    'id': '213898268',
#    'public_metrics': {'followers_count': 10421,
#     'following_count': 3504,
#     'tweet_count': 6018,
#     'listed_count': 48},
#    'username': 'olegdc'},
#   {'name': 'Cannabis NFT Magazine',
#    'id': '1384890873314414592',
#    'public_metrics': {'followers_count': 307,
#     'following_count': 71,
#     'tweet_count': 5611,
#     'listed_count': 10},
#    'username': 'CannabisNFTMag'},
#   {'name': 'J.SBG',
#    'id': '849717589844516864',
#    'public_metrics': {'followers_count': 182,
#     'following_count': 614,
#     'tweet_count': 588,
#     'listed_count': 2},
#    'username': 'Vanillazoo12'},
#   {'name': '🎩MADHATT🎩',
#    'id': '1457455433262649344',
#    'public_metrics': {'followers_count': 2882,
#     'following_count': 948,
#     'tweet_count': 6646,
#     'listed_count': 26},
#    'username': 'CR8MADHATTER'},
#   {'name': 'Billion In a Bag OFFICIAL',
#    'id': '1402732293266022401',
#    'public_metrics': {'followers_count': 3560,
#     'following_count': 247,
#     'tweet_count': 2163,
#     'listed_count': 0},
#    'username': 'Billioninabag'},
#   {'name': 'Everything crypto',
#    'id': '4546717637',
#    'public_metrics': {'followers_count': 549,
#     'following_count': 2335,
#     'tweet_count': 43442,
#     'listed_count': 15},
#    'username': 'bruindesimon'},
#   {'name': 'Alchemist Domainer ➡️Alchemist.co',
#    'id': '1393080356073480192',
#    'public_metrics': {'followers_count': 874,
#     'following_count': 641,
#     'tweet_count': 3391,
#     'listed_count': 5},
#    'username': 'KondoriRaghu'},
#   {'name': 'GrayDogs',
#    'id': '1510331972534554625',
#    'public_metrics': {'followers_count': 95,
#     'following_count': 13,
#     'tweet_count': 281,
#     'listed_count': 0},
#    'username': 'GrayDogsNFT'},
#   {'name': 'thebitcoinwin',
#    'id': '1349987776939360258',
#    'public_metrics': {'followers_count': 64,
#     'following_count': 59,
#     'tweet_count': 3712,
#     'listed_count': 0},
#    'username': 'thebitcoinwin'},
#   {'name': "Sponge'Bob",
#    'id': '1450930228042375170',
#    'public_metrics': {'followers_count': 27,
#     'following_count': 136,
#     'tweet_count': 46,
#     'listed_count': 4},
#    'username': 'Reza3486013'},
#   {'name': 'csCrypto News',
#    'id': '1356389587388682243',
#    'public_metrics': {'followers_count': 72,
#     'following_count': 0,
#     'tweet_count': 6737,
#     'listed_count': 0},
#    'username': 'cscryptonews'},
#   {'name': 'CRYPTO ALERTS',
#    'id': '1382427530314022912',
#    'public_metrics': {'followers_count': 1682,
#     'following_count': 2,
#     'tweet_count': 19043,
#     'listed_count': 12},
#    'username': '_Crypto_Alerts'},
#   {'name': 'Shiller Whale 🐋🌊',
#    'id': '1462707064392671235',
#    'public_metrics': {'followers_count': 311,
#     'following_count': 449,
#     'tweet_count': 6205,
#     'listed_count': 9},
#    'username': 'ShillaWhale'},
#   {'name': 'mdmamunsheikh1',
#    'id': '1474724464898101250',
#    'public_metrics': {'followers_count': 54,
#     'following_count': 1851,
#     'tweet_count': 7516,
#     'listed_count': 6},
#    'username': 'mdmamun66276426'},
#   {'name': 'abstract_queen',
#    'id': '1493804226572525570',
#    'public_metrics': {'followers_count': 57,
#     'following_count': 412,
#     'tweet_count': 178,
#     'listed_count': 2},
#    'username': 'abstra_queen'},
#   {'name': 'Coinzone ⭕️',
#    'id': '1477110935944900610',
#    'public_metrics': {'followers_count': 295,
#     'following_count': 228,
#     'tweet_count': 1813,
#     'listed_count': 15},
#    'username': 'Coinzonestats'},
#   {'name': 'GroteWes',
#    'id': '847329548',
#    'public_metrics': {'followers_count': 68,
#     'following_count': 474,
#     'tweet_count': 1132,
#     'listed_count': 0},
#    'username': 'wesspecial101'},
#   {'name': 'NFT Holding 💎',
#    'id': '3304239502',
#    'public_metrics': {'followers_count': 20317,
#     'following_count': 1072,
#     'tweet_count': 2587,
#     'listed_count': 41},
#    'username': 'NFT_Holding'},
#   {'name': 'Chizzain NFTs',
#    'id': '1473945427678425088',
#    'public_metrics': {'followers_count': 86,
#     'following_count': 286,
#     'tweet_count': 1451,
#     'listed_count': 10},
#    'username': 'Chizzain'},
#   {'name': 'James Vince',
#    'id': '1518781922473693184',
#    'public_metrics': {'followers_count': 2,
#     'following_count': 43,
#     'tweet_count': 13,
#     'listed_count': 0},
#    'username': 'h3xgamesCTO'},
#   {'name': '$Shib Bender 🌬️💨🌪️📈🛸✨',
#    'id': '1395248395137204225',
#    'public_metrics': {'followers_count': 16316,
#     'following_count': 8452,
#     'tweet_count': 46413,
#     'listed_count': 36},
#    'username': 'ShibBender'},
#   {'name': 'Crypto_Pumpd',
#    'id': '1453465302956716039',
#    'public_metrics': {'followers_count': 344,
#     'following_count': 397,
#     'tweet_count': 3360,
#     'listed_count': 28},
#    'username': 'Crypto_Pumpd'},
#   {'name': 'Null TX',
#    'id': '2509810398',
#    'public_metrics': {'followers_count': 34521,
#     'following_count': 10267,
#     'tweet_count': 18236,
#     'listed_count': 1021},
#    'username': 'nulltxnews'},
#   {'name': 'MONA 💎RBXS ELIT💎',
#    'id': '1417938819085651975',
#    'public_metrics': {'followers_count': 267,
#     'following_count': 347,
#     'tweet_count': 6523,
#     'listed_count': 0},
#    'username': 'mona124000'},
#   {'name': 'Rari Verse NFT',
#    'id': '1500855309555879941',
#    'public_metrics': {'followers_count': 11977,
#     'following_count': 0,
#     'tweet_count': 330,
#     'listed_count': 5},
#    'username': 'rariversenft'},
#   {'name': 'First Chiki',
#    'id': '1408453588205068288',
#    'public_metrics': {'followers_count': 235,
#     'following_count': 432,
#     'tweet_count': 4501,
#     'listed_count': 2},
#    'username': 'kidpunknft'},
#   {'name': 'BoredRasta',
#    'id': '1513814455259332609',
#    'public_metrics': {'followers_count': 3,
#     'following_count': 4,
#     'tweet_count': 38,
#     'listed_count': 0},
#    'username': 'BoredRasta'},
#   {'id': '1490716230205915138',
#    'public_metrics': {'followers_count': 1232,
#     'following_count': 1818,
#     'tweet_count': 1668,
#     'listed_count': 30},
#    'username': 'NFTek_news',
#    'name': 'NFTek News || 2424.eth'},
#   {'id': '1487907721877889036',
#    'public_metrics': {'followers_count': 1169,
#     'following_count': 360,
#     'tweet_count': 377,
#     'listed_count': 2},
#    'username': 'BabybudCa',
#    'name': 'Baby Bud'},
#   {'id': '1457350965716213767',
#    'public_metrics': {'followers_count': 382,
#     'following_count': 773,
#     'tweet_count': 2394,
#     'listed_count': 13},
#    'username': 'CryptoNick22',
#    'name': 'Crypto Nick'},
#   {'id': '978373453395955712',
#    'public_metrics': {'followers_count': 235,
#     'following_count': 675,
#     'tweet_count': 11401,
#     'listed_count': 9},
#    'username': 'VeteranOwned1',
#    'name': 'Canadian_Ice'},
#   {'id': '1366774959444492296',
#    'public_metrics': {'followers_count': 98,
#     'following_count': 94,
#     'tweet_count': 151,
#     'listed_count': 4},
#    'username': 'Teddy_POV',
#    'name': 'Teddyy.eth ︱🧸'},
#   {'id': '1495706684458942464',
#    'public_metrics': {'followers_count': 22,
#     'following_count': 1388,
#     'tweet_count': 2016,
#     'listed_count': 0},
#    'username': 'kaowsar_2022',
#    'name': 'Md Nazmul Islam'},
#   {'id': '1506241792156778497',
#    'public_metrics': {'followers_count': 23,
#     'following_count': 381,
#     'tweet_count': 1202,
#     'listed_count': 0},
#    'username': 'mdmamunsheikh03',
#    'name': 'mdmamunsheikh01'},
#   {'id': '1518489720925401088',
#    'public_metrics': {'followers_count': 789,
#     'following_count': 606,
#     'tweet_count': 810,
#     'listed_count': 0},
#    'username': 'DJUglyFatWoman',
#    'name': 'Giu❤️\u200d🔥'},
#   {'id': '1515647589827465216',
#    'public_metrics': {'followers_count': 20,
#     'following_count': 83,
#     'tweet_count': 1573,
#     'listed_count': 1},
#    'username': 'Constantine1623',
#    'name': 'Constantine16'},
#   {'id': '1472846693435527169',
#    'public_metrics': {'followers_count': 34,
#     'following_count': 279,
#     'tweet_count': 280,
#     'listed_count': 24},
#    'username': 'Cartoonologist',
#    'name': 'CountChocula.eth'},
#   {'id': '1478637619974049793',
#    'public_metrics': {'followers_count': 129,
#     'following_count': 1714,
#     'tweet_count': 5604,
#     'listed_count': 13},
#    'username': 'hpranto715',
#    'name': 'Mehedi Hasan♦️⚡'},
#   {'id': '1395152530246705152',
#    'public_metrics': {'followers_count': 209,
#     'following_count': 2235,
#     'tweet_count': 5811,
#     'listed_count': 4},
#    'username': 'RJHG90',
#    'name': 'hrj_g 🌐 #XCUR'},
#   {'id': '1356389587388682243',
#    'public_metrics': {'followers_count': 72,
#     'following_count': 0,
#     'tweet_count': 6737,
#     'listed_count': 0},
#    'username': 'cscryptonews',
#    'name': 'csCrypto News'},
#   {'id': '1508724494181056515',
#    'public_metrics': {'followers_count': 6,
#     'following_count': 1,
#     'tweet_count': 1315,
#     'listed_count': 0},
#    'username': 'nftinvest84',
#    'name': 'nft investor'},
#   {'id': '1420486738745511936',
#    'public_metrics': {'followers_count': 146,
#     'following_count': 87,
#     'tweet_count': 353,
#     'listed_count': 2},
#    'username': '528NFT',
#    'name': 'Airdrop And FreeMint（Earn 100 USDT everyday）'},
#   {'id': '1512767647359942666',
#    'public_metrics': {'followers_count': 278,
#     'following_count': 66,
#     'tweet_count': 104,
#     'listed_count': 0},
#    'username': 'CryptoSurelock',
#    'name': 'Crypto Surelock'},
#   {'id': '1487157788295979010',
#    'public_metrics': {'followers_count': 328,
#     'following_count': 241,
#     'tweet_count': 3701,
#     'listed_count': 1},
#    'username': 'LuckyLucania_',
#    'name': '🅻🆄🅲🅺🆈 🅻🆄🅲🅰🅽🅸🅰'},
#   {'id': '1384497485167697921',
#    'public_metrics': {'followers_count': 2336,
#     'following_count': 502,
#     'tweet_count': 22401,
#     'listed_count': 30},
#    'username': '2021Ufo',
#    'name': '👽🛸🧐 Crypto News--FOLLOW ME🛸👽🧐'},
#   {'id': '1217480994233692160',
#    'public_metrics': {'followers_count': 4557,
#     'following_count': 4767,
#     'tweet_count': 13999,
#     'listed_count': 40},
#    'username': 'jordantheangel_',
#    'name': 'Jordantheangel_'},
#   {'id': '1518730495588065281',
#    'public_metrics': {'followers_count': 4,
#     'following_count': 21,
#     'tweet_count': 13,
#     'listed_count': 0},
#    'username': 'Mrabrando',
#    'name': 'Artur Brando'},
#   {'id': '1489635004003065868',
#    'public_metrics': {'followers_count': 3,
#     'following_count': 29,
#     'tweet_count': 139,
#     'listed_count': 0},
#    'username': 'Sxzte4',
#    'name': 'Len.NFT'},
#   {'id': '1462707064392671235',
#    'public_metrics': {'followers_count': 311,
#     'following_count': 449,
#     'tweet_count': 6205,
#     'listed_count': 9},
#    'username': 'ShillaWhale',
#    'name': 'Shiller Whale 🐋🌊'},
#   {'id': '1403554871052324866',
#    'public_metrics': {'followers_count': 145,
#     'following_count': 690,
#     'tweet_count': 752,
#     'listed_count': 3},
#    'username': 'BourbCrypNFTs',
#    'name': 'Bourbon Crypto NFTs'},
#   {'id': '2776149733',
#    'public_metrics': {'followers_count': 2283,
#     'following_count': 1822,
#     'tweet_count': 8509,
#     'listed_count': 8},
#    'username': 'kennygrey5',
#    'name': 'kenny grey💜'},
#   {'id': '855122324332228608',
#    'public_metrics': {'followers_count': 19,
#     'following_count': 933,
#     'tweet_count': 1846,
#     'listed_count': 0},
#    'username': 'Blzt995',
#    'name': 'B95'},
#   {'id': '1504980125036605443',
#    'public_metrics': {'followers_count': 7,
#     'following_count': 36,
#     'tweet_count': 308,
#     'listed_count': 0},
#    'username': 'BuffHeartsNFT',
#    'name': 'BuffHearts'},
#   {'id': '1387764881533833222',
#    'public_metrics': {'followers_count': 3220,
#     'following_count': 4821,
#     'tweet_count': 1265,
#     'listed_count': 0},
#    'username': 'LitonKh18985282',
#    'name': 'Liton Khan'},
#   {'id': '1260538471049056256',
#    'public_metrics': {'followers_count': 5581,
#     'following_count': 5492,
#     'tweet_count': 8573,
#     'listed_count': 2},
#    'username': 'Amandeep373',
#    'name': 'Amandeep Singh | TVGcoin'},
#   {'id': '1329474283702083586',
#    'public_metrics': {'followers_count': 72,
#     'following_count': 4587,
#     'tweet_count': 9731,
#     'listed_count': 5},
#    'username': 'MdRubeul',
#    'name': 'Md Rubeul Islam'},
#   {'id': '2921809747',
#    'public_metrics': {'followers_count': 4093,
#     'following_count': 4554,
#     'tweet_count': 6400,
#     'listed_count': 2},
#    'username': 'm4yeshar71',
#    'name': '🌺Myesha🌺'},
#   {'id': '2691133580',
#    'public_metrics': {'followers_count': 4346,
#     'following_count': 272,
#     'tweet_count': 25554,
#     'listed_count': 25},
#    'username': 'veazydoezit',
#    'name': 'Veazy'},
#   {'id': '1382427530314022912',
#    'public_metrics': {'followers_count': 1682,
#     'following_count': 2,
#     'tweet_count': 19043,
#     'listed_count': 12},
#    'username': '_Crypto_Alerts',
#    'name': 'CRYPTO ALERTS'},
#   {'id': '1480972504978051072',
#    'public_metrics': {'followers_count': 112,
#     'following_count': 173,
#     'tweet_count': 439,
#     'listed_count': 12},
#    'username': 'AlxndrShabazz',
#    'name': 'Alexander Shabazz'},
#   {'id': '1473474086449946624',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 0,
#     'tweet_count': 478,
#     'listed_count': 0},
#    'username': 'CryptoandSuch',
#    'name': 'CryptoandSuch'},
#   {'id': '1515794684026761222',
#    'public_metrics': {'followers_count': 14,
#     'following_count': 41,
#     'tweet_count': 26,
#     'listed_count': 0},
#    'username': 'BuilderMinotaur',
#    'name': 'Builder Minotaur'},
#   {'id': '1508178445418774531',
#    'public_metrics': {'followers_count': 21,
#     'following_count': 59,
#     'tweet_count': 9,
#     'listed_count': 0},
#    'username': 'MonroeCongreve',
#    'name': 'Md Shoyab Ahmad'},
#   {'id': '1416178488948576257',
#    'public_metrics': {'followers_count': 10862,
#     'following_count': 10301,
#     'tweet_count': 687,
#     'listed_count': 11},
#    'username': 'nftraider',
#    'name': 'NFT Raider'},
#   {'id': '1503538068690767878',
#    'public_metrics': {'followers_count': 74,
#     'following_count': 216,
#     'tweet_count': 4839,
#     'listed_count': 0},
#    'username': 'YellowSub_420',
#    'name': 'Yellow Submarine'},
#   {'id': '1468280210885951492',
#    'public_metrics': {'followers_count': 760,
#     'following_count': 1248,
#     'tweet_count': 35712,
#     'listed_count': 61},
#    'username': 'PartyGuy6969',
#    'name': 'Party Guy'},
#   {'id': '1387793405250473987',
#    'public_metrics': {'followers_count': 7897,
#     'following_count': 392,
#     'tweet_count': 301,
#     'listed_count': 4},
#    'username': 'EmbraceNft',
#    'name': 'EmbraceNFT'},
#   {'id': '67066318',
#    'public_metrics': {'followers_count': 1036,
#     'following_count': 474,
#     'tweet_count': 33698,
#     'listed_count': 44},
#    'username': 'JulCesGarcia',
#    'name': 'jcgarcia.nft'},
#   {'id': '1268732644683952128',
#    'public_metrics': {'followers_count': 307,
#     'following_count': 85,
#     'tweet_count': 2682,
#     'listed_count': 2},
#    'username': 'itzz_DC',
#    'name': 'itzz_DC'},
#   {'id': '84775027',
#    'public_metrics': {'followers_count': 955,
#     'following_count': 262,
#     'tweet_count': 10055,
#     'listed_count': 34},
#    'username': 'ZayaThaFlysta',
#    'name': 'Zaya Tha Flysta'},
#   {'id': '1505740887187460096',
#    'public_metrics': {'followers_count': 10,
#     'following_count': 8,
#     'tweet_count': 14,
#     'listed_count': 0},
#    'username': 'Cristal74398898',
#    'name': 'Cristal'},
#   {'id': '1449529355042844674',
#    'public_metrics': {'followers_count': 674,
#     'following_count': 499,
#     'tweet_count': 570,
#     'listed_count': 1},
#    'username': 'KikaVeVe',
#    'name': 'KikaVeVe ⭕️'},
#   {'id': '1225360716259000320',
#    'public_metrics': {'followers_count': 996,
#     'following_count': 1210,
#     'tweet_count': 937,
#     'listed_count': 0},
#    'username': 'prynxxwisdom',
#    'name': 'Prynxxwisdom'},
#   {'id': '1505480240889753605',
#    'public_metrics': {'followers_count': 129,
#     'following_count': 9,
#     'tweet_count': 8,
#     'listed_count': 0},
#    'username': 'Everincomecoin',
#    'name': 'EverIncome Coin'},
#   {'id': '1410792514697666561',
#    'public_metrics': {'followers_count': 4059,
#     'following_count': 4964,
#     'tweet_count': 7555,
#     'listed_count': 0},
#    'username': 'Jara04403466',
#    'name': 'Jara'},
#   {'id': '1438659136166711296',
#    'public_metrics': {'followers_count': 185,
#     'following_count': 233,
#     'tweet_count': 794,
#     'listed_count': 7},
#    'username': '1stMetaRuffys',
#    'name': 'METAVERSE'},
#   {'id': '1372586799495737346',
#    'public_metrics': {'followers_count': 22,
#     'following_count': 151,
#     'tweet_count': 328,
#     'listed_count': 1},
#    'username': 'Smartcryptoo',
#    'name': 'Ali Baba'},
#   {'id': '1111437546406330368',
#    'public_metrics': {'followers_count': 12,
#     'following_count': 31,
#     'tweet_count': 109,
#     'listed_count': 0},
#    'username': 'MInkredamine',
#    'name': 'Matt Inkredamine'},
#   {'id': '1383153029390667781',
#    'public_metrics': {'followers_count': 253,
#     'following_count': 453,
#     'tweet_count': 1241,
#     'listed_count': 9},
#    'username': 'turkeythebird01',
#    'name': 'Turkey The Bird'},
#   {'id': '1437331777526243333',
#    'public_metrics': {'followers_count': 53,
#     'following_count': 149,
#     'tweet_count': 2061,
#     'listed_count': 8},
#    'username': 'Crypt0_Squ1d',
#    'name': 'Crypt0 Squ1d🦑'},
#   {'id': '1461750874691145731',
#    'public_metrics': {'followers_count': 1223,
#     'following_count': 149,
#     'tweet_count': 198,
#     'listed_count': 0},
#    'username': 'labs_fab',
#    'name': 'Fab Labs'},
#   {'username': 'Crypto_V1sion',
#    'name': '𝐂𝐫𝐲𝐩𝐭𝐨 𝐕𝐢𝐬𝐢𝐨𝐧𝐚𝐫𝐲',
#    'public_metrics': {'followers_count': 11,
#     'following_count': 41,
#     'tweet_count': 72,
#     'listed_count': 0},
#    'id': '1498149540930592791'},
#   {'username': 'Ytchy8',
#    'name': 'Ytchy',
#    'public_metrics': {'followers_count': 4,
#     'following_count': 140,
#     'tweet_count': 692,
#     'listed_count': 0},
#    'id': '1516088578954211329'},
#   {'username': 'mozoseda11',
#    'name': 'Airdropimen',
#    'public_metrics': {'followers_count': 833,
#     'following_count': 1209,
#     'tweet_count': 1917,
#     'listed_count': 0},
#    'id': '1488446011236237313'},
#   {'username': 'makm440',
#    'name': 'Shadin',
#    'public_metrics': {'followers_count': 79,
#     'following_count': 3708,
#     'tweet_count': 9172,
#     'listed_count': 1},
#    'id': '1429044301808472064'},
#   {'username': 'Anthony4600000',
#    'name': 'Antho-Rise Fr',
#    'public_metrics': {'followers_count': 471,
#     'following_count': 271,
#     'tweet_count': 5594,
#     'listed_count': 3},
#    'id': '1453104583404892163'},
#   {'username': 'jpbenting',
#    'name': 'Jean Pierre B.',
#    'public_metrics': {'followers_count': 103,
#     'following_count': 182,
#     'tweet_count': 1399,
#     'listed_count': 1},
#    'id': '3623747235'},
#   {'username': 'OfficialMandox',
#    'name': 'MANDOX',
#    'public_metrics': {'followers_count': 12767,
#     'following_count': 76,
#     'tweet_count': 1370,
#     'listed_count': 19},
#    'id': '1459240521562427392'},
#   {'username': 'JillianValentin',
#    'name': 'JillianValentin.eth',
#    'public_metrics': {'followers_count': 10369,
#     'following_count': 950,
#     'tweet_count': 34498,
#     'listed_count': 69},
#    'id': '18751396'},
#   {'username': 'SoralTrading',
#    'name': 'Soral Trading',
#    'public_metrics': {'followers_count': 697,
#     'following_count': 335,
#     'tweet_count': 2119,
#     'listed_count': 5},
#    'id': '1216284661271261185'},
#   {'username': 'Jayaboards',
#    'name': '여 호온 | Жаыа кусума',
#    'public_metrics': {'followers_count': 273,
#     'following_count': 313,
#     'tweet_count': 3039,
#     'listed_count': 2},
#    'id': '1340661902'},
#   {'username': 'Boniq82',
#    'name': 'boniq',
#    'public_metrics': {'followers_count': 28,
#     'following_count': 141,
#     'tweet_count': 522,
#     'listed_count': 6},
#    'id': '1153362434478022656'},
#   {'username': 'PotatoFriends1',
#    'name': 'Potato Friends',
#    'public_metrics': {'followers_count': 2,
#     'following_count': 0,
#     'tweet_count': 97,
#     'listed_count': 0},
#    'id': '1514920390748893185'},
#   {'username': '_Crypto_Alerts',
#    'name': 'CRYPTO ALERTS',
#    'public_metrics': {'followers_count': 1682,
#     'following_count': 2,
#     'tweet_count': 19043,
#     'listed_count': 12},
#    'id': '1382427530314022912'},
#   {'username': 'EthelLucy11',
#    'name': '22 med abhishek raj',
#    'public_metrics': {'followers_count': 17,
#     'following_count': 58,
#     'tweet_count': 8,
#     'listed_count': 0},
#    'id': '1508278374703280129'},
#   {'username': 'badappleanime',
#    'name': 'rahul kabali',
#    'public_metrics': {'followers_count': 659,
#     'following_count': 831,
#     'tweet_count': 1279,
#     'listed_count': 3},
#    'id': '1487228017566830598'},
#   {'username': 'neeraj_cw',
#    'name': 'CryptoNeeraj',
#    'public_metrics': {'followers_count': 4,
#     'following_count': 10,
#     'tweet_count': 20,
#     'listed_count': 0},
#    'id': '1515209510440562688'},
#   {'username': 'crypticthreadz',
#    'name': 'CrypticThreadz.NFT',
#    'public_metrics': {'followers_count': 188,
#     'following_count': 77,
#     'tweet_count': 8214,
#     'listed_count': 8},
#    'id': '1416547300281815046'},
#   {'username': 'pairology',
#    'name': 'Pairology',
#    'public_metrics': {'followers_count': 2708,
#     'following_count': 2590,
#     'tweet_count': 9506,
#     'listed_count': 13},
#    'id': '1488007966984863748'},
#   {'username': 'JNftdude',
#    'name': 'johnny nftdude',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 1,
#     'tweet_count': 1532,
#     'listed_count': 0},
#    'id': '1509865554223448068'},
#   {'username': 'Gyvran',
#    'name': 'Gibran Quiroga🍥',
#    'public_metrics': {'followers_count': 446,
#     'following_count': 827,
#     'tweet_count': 17740,
#     'listed_count': 9},
#    'id': '50760958'},
#   {'username': 'MetaVapesNFT',
#    'name': 'Meta Vape',
#    'public_metrics': {'followers_count': 8,
#     'following_count': 30,
#     'tweet_count': 4,
#     'listed_count': 0},
#    'id': '1518611709480652800'},
#   {'username': 'METAFLIP1',
#    'name': 'METAFLIP',
#    'public_metrics': {'followers_count': 5816,
#     'following_count': 5,
#     'tweet_count': 469,
#     'listed_count': 4},
#    'id': '1464884921680359437'},
#   {'username': 'PotatoCharacter',
#    'name': 'Potato Friends',
#    'public_metrics': {'followers_count': 21,
#     'following_count': 0,
#     'tweet_count': 128,
#     'listed_count': 0},
#    'id': '1513909258106306560'},
#   {'username': 'graceDy47793524',
#    'name': 'grace Dy',
#    'public_metrics': {'followers_count': 0,
#     'following_count': 3,
#     'tweet_count': 721,
#     'listed_count': 0},
#    'id': '1516928075811893250'},
#   {'username': '_monkeyustoms_',
#    'name': 'MonkeyUstoms',
#    'public_metrics': {'followers_count': 9,
#     'following_count': 36,
#     'tweet_count': 80,
#     'listed_count': 0},
#    'id': '1512400821492793344'},
#   {'username': 'pastorin_nft',
#    'name': 'Pastorin NFT',
#    'public_metrics': {'followers_count': 1286,
#     'following_count': 499,
#     'tweet_count': 1171,
#     'listed_count': 14},
#    'id': '1472730551752798209'},
#   {'username': 'RealClaysCoins',
#    'name': "Clay's Coins",
#    'public_metrics': {'followers_count': 159,
#     'following_count': 144,
#     'tweet_count': 707,
#     'listed_count': 7},
#    'id': '1475296656371367937'},
#   {'username': 'BerriesCrypto',
#    'name': 'Crypto Berries',
#    'public_metrics': {'followers_count': 3567,
#     'following_count': 75,
#     'tweet_count': 3931,
#     'listed_count': 3},
#    'id': '1399004170498232320'},
#   {'username': 'hpranto715',
#    'name': 'Mehedi Hasan♦️⚡',
#    'public_metrics': {'followers_count': 129,
#     'following_count': 1714,
#     'tweet_count': 5604,
#     'listed_count': 13},
#    'id': '1478637619974049793'},
#   {'username': 'cryptonaut101',
#    'name': 'Cryptonaut 🪐',
#    'public_metrics': {'followers_count': 14586,
#     'following_count': 912,
#     'tweet_count': 4806,
#     'listed_count': 16},
#    'id': '1371794577028386821'},
#   {'username': 'M17_Lpunzalan',
#    'name': 'Luis "LZ" Punzalan',
#    'public_metrics': {'followers_count': 542,
#     'following_count': 911,
#     'tweet_count': 12959,
#     'listed_count': 85},
#    'id': '461942103'},
#   {'username': 'Oumarou67348081',
#    'name': 'Oumarou',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 123,
#     'tweet_count': 160,
#     'listed_count': 0},
#    'id': '1393189902334976000'},
#   {'username': 'MarufHa42376100',
#    'name': 'Maruf Hasan',
#    'public_metrics': {'followers_count': 55,
#     'following_count': 848,
#     'tweet_count': 2129,
#     'listed_count': 2},
#    'id': '1262017358396190721'},
#   {'username': 'cryptoepicart',
#    'name': 'crypto epic art',
#    'public_metrics': {'followers_count': 73,
#     'following_count': 76,
#     'tweet_count': 47,
#     'listed_count': 1},
#    'id': '1291736764764295173'},
#   {'username': 'WPstaff',
#    'name': 'ReelsVerse.com',
#    'public_metrics': {'followers_count': 20301,
#     'following_count': 26967,
#     'tweet_count': 26580,
#     'listed_count': 231},
#    'id': '66346482'},
#   {'username': 'MiamiBeachPages',
#    'name': 'Miami ₿each Pages',
#    'public_metrics': {'followers_count': 4955,
#     'following_count': 2406,
#     'tweet_count': 65988,
#     'listed_count': 370},
#    'id': '4668863722'},
#   {'username': 'mobboysNFT',
#    'name': 'Tony',
#    'public_metrics': {'followers_count': 47,
#     'following_count': 146,
#     'tweet_count': 208,
#     'listed_count': 6},
#    'id': '1430637044179644417'},
#   {'username': 'calvo_ar',
#    'name': 'Valtarus',
#    'public_metrics': {'followers_count': 31,
#     'following_count': 261,
#     'tweet_count': 744,
#     'listed_count': 3},
#    'id': '2925206095'},
#   {'username': 'PImaginator',
#    'name': 'potato imaginator',
#    'public_metrics': {'followers_count': 175,
#     'following_count': 265,
#     'tweet_count': 7723,
#     'listed_count': 4},
#    'id': '1210106036427714561'},
#   {'username': 'DaveCrypto2022',
#    'name': 'Dave Crypto',
#    'public_metrics': {'followers_count': 4,
#     'following_count': 1,
#     'tweet_count': 1426,
#     'listed_count': 0},
#    'id': '1508722622808440833'},
#   {'username': 'EvanRoblesC',
#    'name': 'Evan Robles \uea00 | EvanRobles.eth Ξ | Robles.sol 🧬',
#    'public_metrics': {'followers_count': 2371,
#     'following_count': 933,
#     'tweet_count': 902,
#     'listed_count': 12},
#    'id': '1401068403553615872'},
#   {'username': 'Esi34973435',
#    'name': 'Asieh',
#    'public_metrics': {'followers_count': 48,
#     'following_count': 805,
#     'tweet_count': 3450,
#     'listed_count': 2},
#    'id': '1455708455717806083'},
#   {'username': 'CroMagnonPlan',
#    'name': 'Cro-Magnon Plan ♡ #CROFAM',
#    'public_metrics': {'followers_count': 2487,
#     'following_count': 3588,
#     'tweet_count': 1135,
#     'listed_count': 11},
#    'id': '1463932197681995778'},
#   {'username': 'cryptobubbles24',
#    'name': 'СryptoBubblesDaily',
#    'public_metrics': {'followers_count': 61,
#     'following_count': 100,
#     'tweet_count': 742,
#     'listed_count': 7},
#    'id': '999668805583429632'},
#   {'username': 'Esmat71472325',
#    'name': 'Esmat',
#    'public_metrics': {'followers_count': 21,
#     'following_count': 136,
#     'tweet_count': 440,
#     'listed_count': 0},
#    'id': '1484328752108638208'},
#   {'username': 'AngelLija121',
#    'name': 'Angel Lija',
#    'public_metrics': {'followers_count': 1326,
#     'following_count': 1620,
#     'tweet_count': 1007,
#     'listed_count': 1},
#    'id': '1495043053664759810'},
#   {'username': 'TheCrookedCrocs',
#    'name': 'The Crooked Crocs',
#    'public_metrics': {'followers_count': 139,
#     'following_count': 247,
#     'tweet_count': 119,
#     'listed_count': 1},
#    'id': '1478258551722151936'},
#   {'username': 'Sanny23861994',
#    'name': 'Sanny',
#    'public_metrics': {'followers_count': 3868,
#     'following_count': 4335,
#     'tweet_count': 2906,
#     'listed_count': 8},
#    'id': '1487639861620518912'},
#   {'username': 'RajeshJ31601733',
#    'name': 'Rajesh Jana',
#    'public_metrics': {'followers_count': 2,
#     'following_count': 8,
#     'tweet_count': 26,
#     'listed_count': 0},
#    'id': '1478993158549565441'},
#   {'username': 'BastiKaiser',
#    'name': 'Aurelian700',
#    'public_metrics': {'followers_count': 8,
#     'following_count': 77,
#     'tweet_count': 71,
#     'listed_count': 0},
#    'id': '1296399812'},
#   {'username': 'smith7666',
#    'name': 's smith',
#    'public_metrics': {'followers_count': 6,
#     'following_count': 4,
#     'tweet_count': 1198,
#     'listed_count': 0},
#    'id': '1509235612964257792'},
#   {'username': 'prynxxwisdom',
#    'name': 'Prynxxwisdom',
#    'public_metrics': {'followers_count': 996,
#     'following_count': 1210,
#     'tweet_count': 937,
#     'listed_count': 0},
#    'id': '1225360716259000320'},
#   {'username': 'MIXYARD0',
#    'name': '#Crypto🎉',
#    'public_metrics': {'followers_count': 54,
#     'following_count': 1770,
#     'tweet_count': 8023,
#     'listed_count': 7},
#    'id': '1321386627990573057'},
#   {'username': 'NftShopMarket',
#    'name': 'NFT Marketplace',
#    'public_metrics': {'followers_count': 442,
#     'following_count': 2,
#     'tweet_count': 395,
#     'listed_count': 3},
#    'id': '1451891400421871619'},
#   {'username': 'droptown_io',
#    'name': 'droptown.io',
#    'public_metrics': {'followers_count': 576,
#     'following_count': 1679,
#     'tweet_count': 9461,
#     'listed_count': 17},
#    'id': '1376954378595180550'},
#   {'username': 'ahmad_manasrah1',
#    'name': '👑👑CRYPTO KING👑👑',
#    'public_metrics': {'followers_count': 1222,
#     'following_count': 636,
#     'tweet_count': 5071,
#     'listed_count': 51},
#    'id': '800154160456794112'},
#   {'username': '24k_games',
#    'name': '24K GAMES',
#    'public_metrics': {'followers_count': 2733,
#     'following_count': 8,
#     'tweet_count': 50,
#     'listed_count': 0},
#    'id': '1478688013064486916'},
#   {'username': 'ppommppeiicity',
#    'name': 'pompeii 🥑',
#    'public_metrics': {'followers_count': 284,
#     'following_count': 802,
#     'tweet_count': 1113,
#     'listed_count': 1},
#    'id': '1513385196720377856'},
#   {'username': 'Cryptonie1',
#    'name': 'DutchApe',
#    'public_metrics': {'followers_count': 4303,
#     'following_count': 852,
#     'tweet_count': 6627,
#     'listed_count': 20},
#    'id': '976943622422777856'},
#   {'username': '_unbankyourself',
#    'name': 'unbankyourself',
#    'public_metrics': {'followers_count': 262,
#     'following_count': 234,
#     'tweet_count': 9297,
#     'listed_count': 14},
#    'id': '1464618421992185871'},
#   {'public_metrics': {'followers_count': 29,
#     'following_count': 243,
#     'tweet_count': 100,
#     'listed_count': 3},
#    'name': 'Luchenzio',
#    'username': 'Luchenzi0',
# ...
#     'following_count': 1087,
#     'tweet_count': 3416,
#     'listed_count': 3},
#    'id': '1224275334494859265',
#    'username': 'LegitKingla',
#    'name': 'Legit_Kingla'},
#   {'public_metrics': {'followers_count': 0,
#     'following_count': 11,
#     'tweet_count': 244,
#     'listed_count': 0},
#    'id': '1517379695612170240',
#    'username': 'Lebronblack08',
#    'name': 'Lebron J'},
#   {'id': '1293262812547080193',
#    'public_metrics': {'followers_count': 258,
#     'following_count': 506,
#     'tweet_count': 21557,
#     'listed_count': 1},
#    'username': 'prof_shillings',
#    'name': 'shillingcrypto'},
#   {'id': '1518193780389605378',
#    'public_metrics': {'followers_count': 10,
#     'following_count': 197,
#     'tweet_count': 678,
#     'listed_count': 0},
#    'username': 'Raseljr904',
#    'name': 'Rasel mia'},
#   {'id': '1472308007371431937',
#    'public_metrics': {'followers_count': 619,
#     'following_count': 100,
#     'tweet_count': 12217,
#     'listed_count': 3},
#    'username': 'Touraj_samurai',
#    'name': 'Touraj💎RBXS ELITE💎'},
#   {'id': '1475889581010702343',
#    'public_metrics': {'followers_count': 5,
#     'following_count': 21,
#     'tweet_count': 128,
#     'listed_count': 0},
#    'username': 'TheMr_Bear',
#    'name': 'TheMr.Bear'},
#   {'id': '1518806578174267393',
#    'public_metrics': {'followers_count': 27,
#     'following_count': 151,
#     'tweet_count': 357,
#     'listed_count': 0},
#    'username': 'emam9562',
#    'name': 'emam hasan'},
#   {'id': '888748858993504256',
#    'public_metrics': {'followers_count': 370,
#     'following_count': 303,
#     'tweet_count': 299,
#     'listed_count': 6},
#    'username': 'WeFightFraud',
#    'name': 'We Fight Fraud'},
#   {'id': '418116979',
#    'public_metrics': {'followers_count': 2883,
#     'following_count': 4971,
#     'tweet_count': 15061,
#     'listed_count': 25},
#    'username': 'LJF90',
#    'name': '$LJF90'},
#   {'id': '1511969910502887427',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 250,
#     'tweet_count': 337,
#     'listed_count': 0},
#    'username': 'Shanto3466',
#    'name': 'Saiful Islam Shanto'},
#   {'id': '1480895239166459908',
#    'public_metrics': {'followers_count': 11,
#     'following_count': 662,
#     'tweet_count': 858,
#     'listed_count': 3},
#    'username': 'hunted_sharif',
#    'name': 'Hunted Sharif'},
#   {'id': '1447243842344861703',
#    'public_metrics': {'followers_count': 77,
#     'following_count': 521,
#     'tweet_count': 1319,
#     'listed_count': 1},
#    'username': 'Daily__crypto',
#    'name': 'Daily Crypto News'},
#   {'id': '1376954378595180550',
#    'public_metrics': {'followers_count': 576,
#     'following_count': 1679,
#     'tweet_count': 9461,
#     'listed_count': 17},
#    'username': 'droptown_io',
#    'name': 'droptown.io'},
#   {'id': '1469630899767717894',
#    'public_metrics': {'followers_count': 106795,
#     'following_count': 160,
#     'tweet_count': 301,
#     'listed_count': 39},
#    'username': 'metaweartoken',
#    'name': 'MetaWear®'},
#   {'id': '1516068075828768774',
#    'public_metrics': {'followers_count': 8,
#     'following_count': 0,
#     'tweet_count': 221,
#     'listed_count': 0},
#    'username': 'jl_pabilonia',
#    'name': 'JL Pabilonia'},
#   {'id': '1466126083204464647',
#    'public_metrics': {'followers_count': 653,
#     'following_count': 14,
#     'tweet_count': 7903,
#     'listed_count': 4},
#    'username': 'Theta_NFT_BOT',
#    'name': 'Theta NFT BOT | ThetaLands'},
#   {'id': '1413123417415553034',
#    'public_metrics': {'followers_count': 390,
#     'following_count': 1685,
#     'tweet_count': 3759,
#     'listed_count': 2},
#    'username': 'zavira8777',
#    'name': '🛡️{ZAVIRA}🛡️ #NFT'},
#   {'id': '1502479889307340802',
#    'public_metrics': {'followers_count': 22,
#     'following_count': 11,
#     'tweet_count': 851,
#     'listed_count': 0},
#    'username': 'JstforNft',
#    'name': 'SoulNature'},
#   {'id': '1183040561135177731',
#    'public_metrics': {'followers_count': 106,
#     'following_count': 1282,
#     'tweet_count': 3377,
#     'listed_count': 2},
#    'username': 'mojtaba5467',
#    'name': 'mojtaba'},
#   {'id': '1513848624484134915',
#    'public_metrics': {'followers_count': 219,
#     'following_count': 1312,
#     'tweet_count': 40,
#     'listed_count': 3},
#    'username': 'Workartnftclub',
#    'name': 'WorkofartNFTclub'},
#   {'id': '1470269119228526598',
#    'public_metrics': {'followers_count': 759,
#     'following_count': 1545,
#     'tweet_count': 3046,
#     'listed_count': 4},
#    'username': '13751375ff',
#    'name': 'Fatima'},
#   {'id': '1334050840101875714',
#    'public_metrics': {'followers_count': 8326,
#     'following_count': 218,
#     'tweet_count': 6490,
#     'listed_count': 13},
#    'username': 'ckmnewsfeed',
#    'name': 'cryptoknowmics'},
#   {'id': '1479017203290677252',
#    'public_metrics': {'followers_count': 19,
#     'following_count': 10,
#     'tweet_count': 2865,
#     'listed_count': 1},
#    'username': 'panahi_mamad',
#    'name': 'AgeOFF'},
#   {'id': '1517010816188690432',
#    'public_metrics': {'followers_count': 38,
#     'following_count': 389,
#     'tweet_count': 1077,
#     'listed_count': 0},
#    'username': 'ahhalimvai_420',
#    'name': 'MD ABDUL HALIM'},
#   {'id': '1433999647287259137',
#    'public_metrics': {'followers_count': 20,
#     'following_count': 127,
#     'tweet_count': 592,
#     'listed_count': 0},
#    'username': 'JBarquit0',
#    'name': 'JOB'},
#   {'id': '2840951315',
#    'public_metrics': {'followers_count': 134,
#     'following_count': 61,
#     'tweet_count': 1502,
#     'listed_count': 3},
#    'username': 'Taxus_c',
#    'name': 'Layla Henderson'},
#   {'id': '1457448932540395525',
#    'public_metrics': {'followers_count': 579,
#     'following_count': 0,
#     'tweet_count': 3468,
#     'listed_count': 3},
#    'username': 'BoGyANFT',
#    'name': 'BoGyANFT'},
#   {'id': '3310323250',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 21,
#     'tweet_count': 74,
#     'listed_count': 0},
#    'username': 'theworm091',
#    'name': 'Marko'},
#   {'id': '1490076549609054209',
#    'public_metrics': {'followers_count': 8,
#     'following_count': 20,
#     'tweet_count': 111,
#     'listed_count': 11},
#    'username': 'mybabyPandaNFT',
#    'name': 'baby_Panda_NFT'},
#   {'id': '1518583252323160066',
#    'public_metrics': {'followers_count': 18,
#     'following_count': 211,
#     'tweet_count': 517,
#     'listed_count': 0},
#    'username': 'Khokonbd12',
#    'name': 'Khokon Rummon'},
#   {'id': '1517114822260928512',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 1,
#     'tweet_count': 37,
#     'listed_count': 0},
#    'username': 'nftofficial6',
#    'name': 'nft_official'},
#   {'id': '1496426987564453889',
#    'public_metrics': {'followers_count': 34,
#     'following_count': 44,
#     'tweet_count': 1529,
#     'listed_count': 0},
#    'username': 'VickiBrown_',
#    'name': 'Vicki'},
#   {'id': '1484491729000706058',
#    'public_metrics': {'followers_count': 43,
#     'following_count': 14,
#     'tweet_count': 94,
#     'listed_count': 0},
#    'username': 'Cmarketsbeat',
#    'name': 'Cryptomarketsbeat'},
#   {'id': '1515109488851890182',
#    'public_metrics': {'followers_count': 2,
#     'following_count': 3,
#     'tweet_count': 17,
#     'listed_count': 0},
#    'username': 'PigeonCreator',
#    'name': 'The_Pigeon- NFT Creator'},
#   {'id': '1460914783293640707',
#    'public_metrics': {'followers_count': 98,
#     'following_count': 13,
#     'tweet_count': 166,
#     'listed_count': 1},
#    'username': 'CatcationNft',
#    'name': 'Wain | CATCATION'},
#   {'id': '1509865554223448068',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 1,
#     'tweet_count': 1532,
#     'listed_count': 0},
#    'username': 'JNftdude',
#    'name': 'johnny nftdude'},
#   {'id': '3304239502',
#    'public_metrics': {'followers_count': 20317,
#     'following_count': 1072,
#     'tweet_count': 2587,
#     'listed_count': 41},
#    'username': 'NFT_Holding',
#    'name': 'NFT Holding 💎'},
#   {'id': '1469260264247676929',
#    'public_metrics': {'followers_count': 773,
#     'following_count': 1993,
#     'tweet_count': 6268,
#     'listed_count': 0},
#    'username': 'kimfull5',
#    'name': 'Three\xa0precepts'},
#   {'id': '884998159285583872',
#    'public_metrics': {'followers_count': 277,
#     'following_count': 341,
#     'tweet_count': 5192,
#     'listed_count': 10},
#    'username': 'smith77778',
#    'name': 'BostonBruins.eth'},
#   {'id': '1322565828387213312',
#    'public_metrics': {'followers_count': 527,
#     'following_count': 1046,
#     'tweet_count': 19568,
#     'listed_count': 1},
#    'username': 'FirstLa14340074',
#    'name': 'First Last 🇺🇦 The Russian warship is f^cked'},
#   {'id': '1514481234386173954',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 1,
#     'tweet_count': 24,
#     'listed_count': 0},
#    'username': 'InstaNFT1',
#    'name': 'Global Club Of Instanft'},
#   {'id': '1508781841712656385',
#    'public_metrics': {'followers_count': 10,
#     'following_count': 78,
#     'tweet_count': 73,
#     'listed_count': 0},
#    'username': 'dapper_dodo',
#    'name': 'TheDapperDodo'},
#   {'id': '1488278958638514178',
#    'public_metrics': {'followers_count': 10631,
#     'following_count': 4,
#     'tweet_count': 320,
#     'listed_count': 0},
#    'username': 'niftyworld1',
#    'name': 'Nifty World © | FREE NFT Listing Platform'},
#   {'id': '1221075571058397184',
#    'public_metrics': {'followers_count': 3442,
#     'following_count': 4171,
#     'tweet_count': 6251,
#     'listed_count': 0},
#    'username': 'JahanJuly23',
#    'name': 'Nusrat Jahan Jui'},
#   {'id': '1469817580194086914',
#    'public_metrics': {'followers_count': 340,
#     'following_count': 1991,
#     'tweet_count': 6439,
#     'listed_count': 0},
#    'username': 'Ehsan54833478',
#    'name': 'Ehsan'},
#   {'name': 'Habinah Habinah',
#    'id': '1515017478933561347',
#    'public_metrics': {'followers_count': 52,
#     'following_count': 102,
#     'tweet_count': 2876,
#     'listed_count': 0},
#    'username': 'HHabinah'},
#   {'name': 'CatMoon',
#    'id': '1456488210939498508',
#    'public_metrics': {'followers_count': 3233,
#     'following_count': 7,
#     'tweet_count': 111,
#     'listed_count': 4},
#    'username': 'catmooncoin'},
#   {'name': 'Oniket prantor',
#    'id': '1501604399533023232',
#    'public_metrics': {'followers_count': 29,
#     'following_count': 932,
#     'tweet_count': 2848,
#     'listed_count': 0},
#    'username': 'Oniketprantor02'},
#   {'name': "Lucifer's Days",
#    'id': '1503113105936629774',
#    'public_metrics': {'followers_count': 12,
#     'following_count': 11,
#     'tweet_count': 66,
#     'listed_count': 0},
#    'username': 'LucifersDays'},
#   {'name': 'SoulNature',
#    'id': '1502479889307340802',
#    'public_metrics': {'followers_count': 22,
#     'following_count': 11,
#     'tweet_count': 851,
#     'listed_count': 0},
#    'username': 'JstforNft'},
#   {'name': 'Taylor Gibbs',
#    'id': '1422837636654256130',
#    'public_metrics': {'followers_count': 61,
#     'following_count': 93,
#     'tweet_count': 499,
#     'listed_count': 6},
#    'username': 'TaylorGibbsly'},
#   {'name': 'Sona Global 🔶',
#    'id': '1403502457867493376',
#    'public_metrics': {'followers_count': 155,
#     'following_count': 987,
#     'tweet_count': 2092,
#     'listed_count': 7},
#    'username': 'Vy0072'},
#   {'name': 'Sorare jouons ensemble ⚽️',
#    'id': '1485269178961612803',
#    'public_metrics': {'followers_count': 32,
#     'following_count': 132,
#     'tweet_count': 321,
#     'listed_count': 0},
#    'username': 'crypto_sorare'},
#   {'name': 'StanokCrypto📈📊',
#    'id': '1245891278774185987',
#    'public_metrics': {'followers_count': 692,
#     'following_count': 583,
#     'tweet_count': 1017,
#     'listed_count': 0},
#    'username': 'stanokcrypto'},
#   {'name': 'WP-Developer',
#    'id': '1480141883808497664',
#    'public_metrics': {'followers_count': 22,
#     'following_count': 110,
#     'tweet_count': 70,
#     'listed_count': 0},
#    'username': 'Kamalahmad2000'},
#   {'name': 'UX Links',
#    'id': '21915540',
#    'public_metrics': {'followers_count': 50716,
#     'following_count': 44,
#     'tweet_count': 15476,
#     'listed_count': 2639},
#    'username': 'uxlinks'},
#   {'name': 'droptown.io',
#    'id': '1376954378595180550',
#    'public_metrics': {'followers_count': 576,
#     'following_count': 1679,
#     'tweet_count': 9461,
#     'listed_count': 17},
#    'username': 'droptown_io'},
#   {'name': 'Nøvember',
#    'id': '1367495325439655936',
#    'public_metrics': {'followers_count': 199,
#     'following_count': 378,
#     'tweet_count': 529,
#     'listed_count': 4},
#    'username': 'Nvember8'},
#   {'name': 'Centurion Invest',
#    'id': '1504467231249367049',
#    'public_metrics': {'followers_count': 33,
#     'following_count': 19,
#     'tweet_count': 57,
#     'listed_count': 0},
#    'username': 'C3NTUR10N1NV3ST'},
#   {'name': 'Billionaire Key',
#    'id': '1515310965256069122',
#    'public_metrics': {'followers_count': 70,
#     'following_count': 967,
#     'tweet_count': 18,
#     'listed_count': 0},
#    'username': 'BillionaireKeyy'},
#   {'name': 'Fire Birds',
#    'id': '1348400910423252998',
#    'public_metrics': {'followers_count': 135,
#     'following_count': 7,
#     'tweet_count': 4,
#     'listed_count': 1},
#    'username': 'birdsomni'},
#   {'name': 'Fatima',
#    'id': '1470269119228526598',
#    'public_metrics': {'followers_count': 759,
#     'following_count': 1545,
#     'tweet_count': 3046,
#     'listed_count': 4},
#    'username': '13751375ff'},
#   {'name': 'szotyi',
#    'id': '1495094918187995146',
#    'public_metrics': {'followers_count': 31,
#     'following_count': 111,
#     'tweet_count': 134,
#     'listed_count': 0},
#    'username': 'szotyimarci1'},
#   {'name': '🖊️👨🏻\u200d💼 𝕠𝕫𝕔𝕒𝕤𝕥𝕚𝕝𝕝𝕠.𝕖𝕥𝕙 👨🏻\u200d💻🔛',
#    'id': '197563337',
#    'public_metrics': {'followers_count': 15005,
#     'following_count': 16506,
#     'tweet_count': 62961,
#     'listed_count': 201},
#    'username': 'OzCastillo'},
#   {'name': 'Token 10X: Coin listing | Crypto news | Reviews',
#    'id': '3363651669',
#    'public_metrics': {'followers_count': 21164,
#     'following_count': 783,
#     'tweet_count': 5772,
#     'listed_count': 2},
#    'username': 'token10x'},
#   {'name': 'cryptolover',
#    'id': '1475157773621022723',
#    'public_metrics': {'followers_count': 5,
#     'following_count': 120,
#     'tweet_count': 195,
#     'listed_count': 4},
#    'username': 'crypto_loverF'},
#   {'name': 'Ireen 🇺🇦❤️',
#    'id': '1463523832971497478',
#    'public_metrics': {'followers_count': 2644,
#     'following_count': 1066,
#     'tweet_count': 10299,
#     'listed_count': 38},
#    'username': 'MoonIreen'},
#   {'name': 'Nifty World © | FREE NFT Listing Platform',
#    'id': '1488278958638514178',
#    'public_metrics': {'followers_count': 10631,
#     'following_count': 4,
#     'tweet_count': 320,
#     'listed_count': 0},
#    'username': 'niftyworld1'},
#   {'name': 'Party Guy',
#    'id': '1468280210885951492',
#    'public_metrics': {'followers_count': 760,
#     'following_count': 1248,
#     'tweet_count': 35712,
#     'listed_count': 61},
#    'username': 'PartyGuy6969'},
#   {'name': 'johnny nftdude',
#    'id': '1509865554223448068',
#    'public_metrics': {'followers_count': 1,
#     'following_count': 1,
#     'tweet_count': 1532,
#     'listed_count': 0},
#    'username': 'JNftdude'},
#   {'name': 'NFT Holding 💎',
#    'id': '3304239502',
#    'public_metrics': {'followers_count': 20317,
#     'following_count': 1072,
#     'tweet_count': 2587,
#     'listed_count': 41},
#    'username': 'NFT_Holding'},
#   {'name': 'Domaindealer.x | 5710.eth | kue.eth 🇺🇦🕊',
#    'id': '1408084806781607937',
#    'public_metrics': {'followers_count': 557,
#     'following_count': 721,
#     'tweet_count': 6383,
#     'listed_count': 25},
#    'username': 'Domainclubx'},
#   {'name': 'Rasel mia',
#    'id': '1518193780389605378',
#    'public_metrics': {'followers_count': 10,
#     'following_count': 197,
#     'tweet_count': 678,
#     'listed_count': 0},
#    'username': 'Raseljr904'},
#   {'name': 'Fernandoo',
#    'id': '1426492825038774274',
#    'public_metrics': {'followers_count': 5869,
#     'following_count': 5864,
#     'tweet_count': 533,
#     'listed_count': 0},
#    'username': 'Fernandoo690'},
#   {'name': 'CryptoSmart',
#    'id': '1322360439083163650',
#    'public_metrics': {'followers_count': 1032,
#     'following_count': 377,
#     'tweet_count': 16456,
#     'listed_count': 9},
#    'username': 'NFTCryptoSmart'},
#   ...]}

# %%
follower_data = pd.DataFrame(follower_data_raw["users"])
# follower_data.groupby("author_id")
# follower_data = follower_data.drop(columns="geo")
follower_data
# Out:
#                         id                                     public_metrics  \
# 0      1181641903009341440  {'followers_count': 509, 'following_count': 51...
# 1      1441693405583593478  {'followers_count': 5, 'following_count': 56, ...
# 2               3008000582  {'followers_count': 556, 'following_count': 13...
# 3      1208948613189160961  {'followers_count': 477, 'following_count': 74...
# 4               2542802983  {'followers_count': 433, 'following_count': 36...
# ...                    ...                                                ...
# 15299   755561434931572737  {'followers_count': 7, 'following_count': 65, ...
# 15300  1464617797011623939  {'followers_count': 0, 'following_count': 11, ...
# 15301  1519004956136816642  {'followers_count': 1620, 'following_count': 8...
# 15302  1517595559011528705  {'followers_count': 6463, 'following_count': 2...
# 15303             18957343  {'followers_count': 7859, 'following_count': 5...
#
#               username                           name
# 0      cryptoken_board              cryptoken board ℠
# 1       AliGhiasvand77                  Anonymous boy
# 2            Jeruk4444                      █║Nash║▌🌟
# 3           BeckerrJon  Jonathan Becker | jbecker.eth
# 4            DaLeewoke                     DaLee Woke
# ...                ...                            ...
# 15299    omar_fahimi99                       mr zbida
# 15300  WirghtElizabeth               Wirght Elizabeth
# 15301        MoveningE              Movening Official
# 15302    tradebots_sol                     Trade Bots
# 15303   TheRealElusive                      ELUSIVE🍍💜
#
# [15304 rows x 4 columns]
